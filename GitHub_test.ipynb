# %% [markdown]
# ## Example CoLab notebook - MUST BE RUN IN CHROME BROWSER
#
# ### N.B. this is a quick and dirty example and only a test of concept rather than anything resembling a distributable product.
#
# #### This will notebook will provide a very quick tutorial, install the FORCsensei package, upload some raw data and plot
#
# This notebook can be accessed at: https://colab.research.google.com/github/FORCaist/forcsensei/blob/master/GitHub_test.ipynb

# %% [markdown]
# #### To start, select the code cell below this text and press ```shift``` and ```Enter``` together. This will load the brief tutorial video, demonstrating how to use the notebook.

# %%
from IPython.display import YouTubeVideo
id = 'JkTm9Bfh9dw'
YouTubeVideo(id=id,autoplay=True)

# %%
# !pip install --upgrade git+https://github.com/FORCaist/forcsensei.git #install FORCsensei

import forcsensei as fs
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded FORC file "{name}"'.format(name=fn))

H, Hr, M, Fk, Fj, Ft, dH = fs.parse_measurements(fn)
plt.plot(H,M,'.')
plt.show()
